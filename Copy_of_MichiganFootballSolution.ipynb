# %% [markdown]
# I pulled all teh data from here: https://www.sports-reference.com/cfb/conferences/big-ten/2023-schedule.html

# %%
scores = [("08/31/2023", "Minneapolis, Minnesota", "Minnesota 13, Nebraska 10"),
("09/01/2023", "East Lansing, Michigan", "Michigan State 31, Central Mich. 7"),
("09/02/2023", "Ann Arbor, Michigan", "Michigan 30, East Carolina 3"),
("09/02/2023", "West Lafayette, Indiana", "Purdue 35, Fresno St. 39"),
("09/02/2023", "Iowa City, Iowa", "Iowa 24, Utah St. 14"),
("09/02/2023", "Bloomington, Indiana", "Indiana 3, Ohio State 23"),
("09/02/2023", "College Park, Maryland", "Maryland 38, Towson 6"),
("09/02/2023", "Madison, Wisconsin", "Wisconsin 38, Buffalo 17"),
("09/02/2023", "University Park, Pennsylvania", "Penn State 38, West Virginia 15"),
("09/02/2023", "Champaign, Illinois", "Illinois 30, Toledo 28"),
("09/03/2023", "Piscataway, New Jersey", "Rutgers 24, Northwestern 7"),
("09/08/2023", "Bloomington, Indiana", "Indiana 41, Indiana St. 7"),
("09/08/2023", "Lawrence, Kansas", "Illinois 23, Kansas 34"),
("09/09/2023", "Minneapolis,", "Minnesota 25, Eastern Mich. 6"),
("09/09/2023", "Boulder, Colorado", "Nebraska 14, Colorado 36"),
("09/09/2023", "East Lansing, Michigan", "Michigan State 45, Richmond 14"),
("09/09/2023", "Ann Arbor, Michigan", "Michigan 35, UNLV 7"),
("09/09/2023", "Blacksburg, Virginia", "Purdue 24, Virginia Tech 17"),
("09/09/2023", "Ames, Iowa", "Iowa 20, Iowa State 13"),
("09/09/2023", "Columbus, Ohio", "Ohio State 35, Youngstown State 7"),
("09/09/2023", "College Park, Maryland", "Maryland 38, Charlotte 20"),
("09/09/2023", "Pullman, Washington", "Wisconsin 22, Washington St. 31"),
("09/09/2023", "University Park, Pennsylvania", "Penn State 63, Delaware 7"),
("09/09/2023", "Piscataway, New Jersey", "Rutgers 36, Temple 7"),
("09/09/2023", "Evanston, Illinois", "Northwestern 38, UTEP 7"),
("09/15/2023", "College Park, Maryland", "Maryland 42, Virginia 14"),
("09/16/2023", "Chapel Hill, North Carolina", "Minnesota 13, North Carolina 31"),
("09/16/2023", "Lincoln, Nebraska", "Nebraska 35, NIU 11"),
("09/16/2023", "East Lansing, Michigan", "Michigan State 7, Washington 41"),
("09/16/2023", "Ann Arbor, Michigan", "Michigan 31, Bowling Green 6"),
("09/16/2023", "West Lafayette, Indiana", "Purdue 20, Syracuse 35"),
("09/16/2023", "Iowa City, Iowa", "Iowa 41, Western Mich. 10"),
("09/16/2023", "Indianapolis, Indiana", "Indiana 14, Louisville 21"),
("09/16/2023", "Columbus, Ohio", "Ohio State 63, Western Kentucky 10"),
("09/16/2023", "Madison, Wisconsin", "Wisconsin 35, Ga. Southern 14"),
("09/16/2023", "Champaign, Illinois", "Penn State 30, Illinois 13"),
("09/16/2023", "Piscataway, New Jersey", "Rutgers 35, Virginia Tech 16"),
("09/16/2023", "Durham, North Carolina", "Northwestern 14, Duke 38"),
("09/22/2023", "West Lafayette, Indiana", "Purdue 17, Wisconsin 38"),
("09/23/2023", "Evanston, Illinois", "Minnesota 34, Northwestern 37"),
("11/04/2023", "Piscataway, New Jersey", "Ohio State 35, Rutgers 16"),
("11/04/2023", "College Park, Maryland", "Maryland 15, Penn State 51"),
("11/11/2023", "West Lafayette, Indiana", "Minnesota 30, Purdue 49"),
("11/11/2023", "Lincoln, Nebraska", "Nebraska 10, Maryland 13"),
("11/11/2023", "Columbus, Ohio", "Michigan State 3, Ohio State 38"),
("11/11/2023", "University Park, Pennsylvania", "Michigan 24, Penn State 15"),
("11/11/2023", "Iowa City, Iowa", "Iowa 22, Rutgers 0"),
("11/11/2023", "Champaign, Illinois", "Indiana 45, Illinois 48"),
("11/11/2023", "Madison, Wisconsin", "Wisconsin 10, Northwestern 24"),
("11/11/2023", "Iowa City, Iowa", "Rutgers 0, Iowa 22"),
("11/18/2023", "Columbus, Ohio", "Minnesota 3, Ohio State 37"),
("11/18/2023", "Madison, Wisconsin", "Nebraska 17, Wisconsin 24"),
("11/18/2023", "Bloomington, Indiana", "Michigan State 24, Indiana 21"),
("11/18/2023", "College Park, Maryland", "Michigan 31, Maryland 24"),
("11/18/2023", "Evanston, Ill.,", "Purdue 15, Northwestern 23"),
("11/18/2023", "Iowa City, Iowa, Iowa", "Iowa 15, Illinois 13"),
("11/18/2023", "University Park, Pennsylvania", "Penn State 27, Rutgers 6"),
("11/24/2023", "Lincoln, Nebraska", "Nebraska 10, Iowa 13"),
("11/24/2023", "Detroit, Michigan", "Michigan State 0, Penn State 42"),
("11/25/2023", "Minneapolis, Minnesota", "Minnesota 14, Wisconsin 28"),
("11/25/2023", "Ann Arbor, Michigan", "Michigan 30, Ohio State 24"),
("11/25/2023", "West Lafayette, Indiana", "Purdue 35, Indiana 31"),
("11/25/2023", "Piscataway, New Jersey", "Maryland 42, Rutgers 24"),
("11/25/2023", "Champaign, Illinois", "Illinois 43, Northwestern 45"),
("11/25/2023", "Piscataway, New Jersey", "Rutgers 24, Maryland 42")]

def identifyTeamsAndScores(input_string):
  # Split the input string at the comma
  teams_and_scores = input_string.split(', ')

  # Extract team names and scores
  team1, score1 = teams_and_scores[0].rsplit(' ', 1)
  team2, score2 = teams_and_scores[1].rsplit(' ', 1)

  # Convert scores to integers
  score1 = int(score1)
  score2 = int(score2)

  '''

  # Print or use the extracted values
  print(f"Team 1: {team1}, Score 1: {score1}")
  print(f"Team 2: {team2}, Score 2: {score2}")
  '''

  return team1, score1, team2, score2

for x in scores:
  identifyTeamsAndScores(x[2])

# %%
class Vertex:
  def __init__(self, key):
    self.id = key
    self.connectedTo = {}
    self.degree = 0
  def addNeighbor(self, nbr, weight=0):
    self.connectedTo[nbr] = weight
  def getId(self):
    return self.id
  def getWeight(self, nbr):
    return self.connectedTo[nbr]
  def getConnections(self):
    return self.connectedTo.keys()
  def calcDegree(self):
     self.degree = len(self.connectedTo.keys())

  def __str__(self):
    #return str(self.id) + ‘is connected to ‘ + str((x.id, x.weight) for x in self.connectedTo)
    return str(self.id) + ' connectedTo: ' + str([x.id for x in self.connectedTo])

class Graph:
    def __init__(self):
        self.vertList = {}
        self.numVertices = 0

    def addVertex(self,key):
        self.numVertices = self.numVertices + 1
        newVertex = Vertex(key)
        self.vertList[key] = newVertex
        return newVertex

    def getVertex(self,n):
        if n in self.vertList:
            return self.vertList[n]
        else:
            return None

    def __contains__(self,n):
        return n in self.vertList

    def addEdge(self,f,t,weight=0):
        if f not in self.vertList:
            nv = self.addVertex(f)
        if t not in self.vertList:
            nv = self.addVertex(t)
        self.vertList[f].addNeighbor(self.vertList[t], weight)

    def getVertices(self):
        return self.vertList.keys()

    def __iter__(self):
        return iter(self.vertList.values())
    def page_rank(self, iterations=100, damping_factor=0.85):
        # Initialize the rank of each vertex
        totalVertices = self.numVertices
        ranks = {vertex.getId(): 1/totalVertices for vertex in self.vertList.values()}

        # Calculate the PageRank over a series of iterations
        for _ in range(iterations):
            new_ranks = {}
            for vertex in self.vertList.values():
                # Start with the base rank contributed by random jumps
                new_rank = (1 - damping_factor) / totalVertices
                # Sum the contributions from each vertex connected to this one
                for v in self.vertList.values():
                    if vertex in v.getConnections():
                        new_rank += damping_factor * (ranks[v.getId()] / v.degree)
                new_ranks[vertex.getId()] = new_rank
            ranks = new_ranks

        # Update the ranks in the vertices (optional, if you want to store the ranks in the vertices)
        for vertex in self.vertList.values():
            vertex.pageRank = ranks[vertex.getId()]

        return ranks

# %%
season = Graph()
for game in scores:
  team1, score1, team2, score2 = identifyTeamsAndScores(game[2])
   # Add edges to the graph (loser to winner)
  if score1 > score2:
    season.addEdge(team2, team1)
  elif score2 > score1:
    season.addEdge(team1, team2)

# %%
# Print the edges in the graph
print("vertices in the graph:")
for vert in season.vertList:
    print(season.vertList[vert])
    season.vertList[vert].calcDegree()
# Out:
# vertices in the graph:
# Nebraska connectedTo: ['Minnesota', 'Colorado', 'Michigan', 'Michigan State', 'Maryland', 'Wisconsin', 'Iowa']
# Minnesota connectedTo: ['North Carolina', 'Northwestern', 'Michigan', 'Illinois', 'Purdue', 'Ohio State', 'Wisconsin']
# Central Mich. connectedTo: ['Michigan State']
# Michigan State connectedTo: ['Washington', 'Maryland', 'Iowa', 'Rutgers', 'Michigan', 'Minnesota', 'Ohio State', 'Penn State']
# East Carolina connectedTo: ['Michigan']
# Michigan connectedTo: []
# Purdue connectedTo: ['Fresno St.', 'Syracuse', 'Wisconsin', 'Iowa', 'Ohio State', 'Nebraska', 'Michigan', 'Northwestern']
# Fresno St. connectedTo: []
# Utah St. connectedTo: ['Iowa']
# Iowa connectedTo: ['Penn State', 'Minnesota']
# Indiana connectedTo: ['Ohio State', 'Louisville', 'Maryland', 'Michigan', 'Rutgers', 'Penn State', 'Illinois', 'Michigan State', 'Purdue']
# Ohio State connectedTo: ['Michigan']
# Towson connectedTo: ['Maryland']
# ...

# %%
vars(season.vertList['Michigan'])
# Out:
# {'id': 'Michigan', 'connectedTo': {}, 'degree': 0}

# %%
#calculate the ranks
RankDict = season.page_rank()

sorted_dict = sorted(RankDict.items(), key=lambda item: item[1], reverse=True)
for x in sorted_dict:
  print(x)
# Out:
# ('Michigan', 0.06368135924880475)
# ('Ohio State', 0.035024127969423356)
# ('Penn State', 0.030286002830903734)
# ('Iowa', 0.022414730259052926)
# ('Minnesota', 0.019504645992345304)
# ('Northwestern', 0.017533621645367557)
# ('Wisconsin', 0.015756227296989223)
# ('Maryland', 0.01515768689740611)
# ('Rutgers', 0.013501340603358811)
# ('Illinois', 0.01325729396343322)
# ('Nebraska', 0.01289055061296233)
# ('Indiana', 0.01004219500412453)
# ('Michigan State', 0.009877347037663391)
# ('Purdue', 0.008813028730589773)
# ('Duke', 0.005707988406985212)
# ('Washington St.', 0.005405831367760895)
# ('North Carolina', 0.005095694026343228)
# ('Kansas', 0.004337086994261047)
# ('Colorado', 0.004292553873132439)
# ('Washington', 0.003776740850024463)
# ('Louisville', 0.0036757022554400444)
# ('Fresno St.', 0.003663657029897891)
# ('Syracuse', 0.003663657029897891)
# ('Central Mich.', 0.0027272727272727275)
# ('East Carolina', 0.0027272727272727275)
# ('Utah St.', 0.0027272727272727275)
# ...
